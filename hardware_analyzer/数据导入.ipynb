# %%
import os
# import csv
import django
from django.conf import settings

# 设置 Django 环境
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'hardware_analyzer.settings')
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'
django.setup()

from analyzer.models import GPU

def import_gpu_data(csv_file_path):
    # 清空表（可选）
    GPU.objects.all().delete()
    print("已清空现有 GPU 数据")

    # 导入 CSV 数据
    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            GPU.objects.create(
                title=row['标题'],
                reference_price=row['参考价'] or None,
                jd_price=row['京东价'] or None
            )

    # 检查导入结果
    print(f"成功导入 {GPU.objects.count()} 条 GPU 数据")
    for gpu in GPU.objects.all():
        print(f"ID: {gpu.id}, Title: {gpu.title}, 参考价: {gpu.reference_price}, 京东价: {gpu.jd_price}")

if __name__ == "__main__":
    csv_file_path = '../spider/csv/gpunvidia.csv'  # 默认路径，可改为实际路径
    import_gpu_data(csv_file_path)
# Out:
# 已清空现有 GPU 数据
# 成功导入 1530 条 GPU 数据
# ID: 899, Title: 小影霸GT 210 PRO 1G D3 疾影, 参考价: 169, 京东价: 139.0
# ID: 900, Title: 铭影GT 610 2G D3 刀锋版, 参考价: 169, 京东价: None
# ID: 901, Title: 昂达GT710典范 1GD3静音版, 参考价: 199, 京东价: None
# ID: 902, Title: 铭鑫视界风 GT710N-2GBD3 FIGHT版, 参考价: 215, 京东价: None
# ID: 903, Title: 铭瑄 MS-GT710 重锤II, 参考价: 239, 京东价: None
# ID: 904, Title: 昂达GT710典范 2GD3静音版, 参考价: 239, 京东价: None
# ID: 905, Title: 盈通GT710 2G D3 战神版, 参考价: 249, 京东价: None
# ID: 906, Title: 升技GT 710 2G D3, 参考价: 259, 京东价: None
# ID: 907, Title: 劲鲨Geforce GTX650 1GB, 参考价: 266, 京东价: None
# ID: 908, Title: 精粤GT 730 4G D3-A, 参考价: 268, 京东价: None
# ID: 909, Title: 铭瑄 MS-GT710 重锤II 2G, 参考价: 279, 京东价: None
# ID: 910, Title: 华硕GT710-SL-1GD5-BRK, 参考价: 279, 京东价: None
# ID: 911, Title: 小影霸GT730 1G D3, 参考价: 289, 京东价: None
# ID: 912, Title: 铭瑄 GT 710重锤PLUS 2G, 参考价: 299, 京东价: None
# ID: 913, Title: 旌宇GF210 1G x1, 参考价: 299, 京东价: 399.0
# ID: 914, Title: 欧比亚GT710-1G, 参考价: 299, 京东价: None
# ...

# %%
import os
import csv
import django
from django.conf import settings

# 设置 Django 环境
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'hardware_analyzer.settings')
os.environ['DJANGO_ALLOW_ASYNC_UNSAFE'] = 'true'
django.setup()

from analyzer.models import CPU

def import_cpu_data(csv_file_path):
    # 清空表（可选）
    # CPU.objects.all().delete()
    # print("已清空现有 CPU 数据")

    # 导入 CSV 数据
    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            CPU.objects.create(
                title=row['标题'],
                reference_price=row['参考价'] or None,
                jd_price=row['京东价'] or None
            )

    # 检查导入结果
    print(f"成功导入 {CPU.objects.count()} 条 CPU 数据")
    for cpu in CPU.objects.all():
        print(f"ID: {cpu.id}, Title: {cpu.title}, 参考价: {cpu.reference_price}, 京东价: {cpu.jd_price}")

if __name__ == "__main__":
    csv_file_path = '../spider/csv/cpuamd.csv'  # 默认路径，可改为实际路径
    import_cpu_data(csv_file_path)
# Out:
# 成功导入 194 条 CPU 数据
# ID: 66, Title: Intel 赛扬 G5900, 参考价: 289, 京东价: None
# ID: 67, Title: Intel 赛扬 G5905, 参考价: 290, 京东价: None
# ID: 68, Title: Intel 赛扬 G4930, 参考价: 339, 京东价: None
# ID: 69, Title: Intel 赛扬 G5925, 参考价: 389, 京东价: None
# ID: 70, Title: Intel 赛扬 G5920, 参考价: 399, 京东价: None
# ID: 71, Title: Intel 奔腾金牌 G6405, 参考价: 430, 京东价: 489.0
# ID: 72, Title: Intel 奔腾金牌 G6400, 参考价: 499, 京东价: None
# ID: 73, Title: Intel 奔腾金牌 G5420, 参考价: 509, 京东价: None
# ID: 74, Title: Intel 奔腾双核 G4400, 参考价: 538, 京东价: None
# ID: 75, Title: Intel 酷睿i3 10105F, 参考价: 560, 京东价: None
# ID: 76, Title: Intel 奔腾 G5500, 参考价: 599, 京东价: None
# ID: 77, Title: Intel 酷睿i3 10100F, 参考价: 630, 京东价: 899.0
# ID: 78, Title: Intel 奔腾金牌 G7400, 参考价: 679, 京东价: None
# ID: 79, Title: Intel 酷睿 i3 14100F, 参考价: 699, 京东价: 699.0
# ID: 80, Title: Intel 酷睿i3 10105, 参考价: 790, 京东价: 699.0
# ID: 81, Title: Intel 酷睿i3 9100F, 参考价: 799, 京东价: 139.0
# ID: 82, Title: Intel 酷睿 i3 12100F, 参考价: 850, 京东价: 549.0
# ...
